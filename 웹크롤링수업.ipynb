# %%
import requests
from bs4 import BeautifulSoup
res = requests.get('https://www.codeit.kr/courses/data-science')
soup = BeautifulSoup(res.content, 'html.parser')# 비정형 데이터
mydata = soup.find('strong')
print(mydata.get_text())
# Out:
# 질문하기

# %%
from bs4 import BeautifulSoup
html =      "<html> \
                <body> \
                        <h1 id='title'>[1]크롤링이란?</h1> \
                        <p class='cssstyle'>웹페이지에서 필요한 데이터를 추출하는 것</p> \
                        <p id='body' align='center'>파이썬을 중심으로 다양한 웹크롤링 기술 발달</p> \
                </body> \
            </html>"
soup = BeautifulSoup(html,"html.parser")
# 태그로 검색 방법
data = soup.find('p')
print(data.string)
# Out:
# 웹페이지에서 필요한 데이터를 추출하는 것

# %%
data = soup.find('p', class_ = 'cssstyle')
data.string
# Out:
# '웹페이지에서 필요한 데이터를 추출하는 것'

# %%
data = soup.find('p', attrs = {'align' : 'center'})
data.string
# Out:
# '파이썬을 중심으로 다양한 웹크롤링 기술 발달'

# %%
data = soup.find('p', 'cssstyle')
data.string
# Out:
# '웹페이지에서 필요한 데이터를 추출하는 것'

# %%
paragraph_data = soup.find_all('p')

for paragraph in paragraph_data:
    print(paragraph.get_text())
# Out:
# 웹페이지에서 필요한 데이터를 추출하는 것
# 파이썬을 중심으로 다양한 웹크롤링 기술 발달

# %%
paragraph_data = soup.find_all('body')

for paragraph in paragraph_data:
    print(paragraph.get_text())
# Out:
#  [1]크롤링이란? 웹페이지에서 필요한 데이터를 추출하는 것 파이썬을 중심으로 다양한 웹크롤링 기술 발달

# %%
import requests
from bs4 import BeautifulSoup

res = requests.get('https://news.v.daum.net/v/20210504152604800')
soup = BeautifulSoup(res.content, 'html.parser')
title = soup.find('h3', 'tit_view')
print(title.get_text())
# Out:
# 임혜숙, '논문 내조' 적극 반박..여당도 "퀴리부인도 남편과 연구" 옹호

# %%
date = soup.find('span', 'num_date')
print(date.get_text())
# Out:
# 2021. 05. 04. 15:26

# %%
press_list = soup.find_all('span', 'txt_info')
for press in press_list:
    print(press.get_text())

print()
print(press_list[0].get_text())
print(press_list[1].get_text())
print(press_list[2].get_text())
# Out:
# 오연서
# 입력 2021. 05. 04. 15:26
# 수정 2021. 05. 04. 22:36
#
# 오연서
# 입력 2021. 05. 04. 15:26
# 수정 2021. 05. 04. 22:36

# %%
li_list = soup.find_all('li')
for list in li_list:
    print(list.get_text())
# Out:
# 연예
# 스포츠
# 홈
# 사회
# 정치
# 경제
# 국제
# 문화
# IT
# 랭킹
# 연재
# 포토
# TV
# 1boon
# 갤러리
#   남성
#   여성
#   느림
#   보통
#   빠름
#    English
#    简体中文
#    日本語
#    Bahasa Indonesia
#    tiếng Việt
#    한국어
#     가나다라마바사 매우 작은 폰트
#     가나다라마바사 작은 폰트
#     가나다라마바사 보통 폰트
#     가나다라마바사 큰 폰트
#     가나다라마바사 매우 큰 폰트
# ‘캘리포니아 변이’ 손놓고 있던 당국 “지난달 경북 확진자 절반”
# 미궁 빠진 ‘한강 대학생 사망’…이틀새 21만명 진상규명 청원
# 검찰, ‘박사방’ 조주빈 항소심서도 무기징역 구형
# 경찰, ‘해직 교사 특채’ 의혹 조희연 교육감 사건 공수처로
# SBS ‘요한, 씨돌, 용현’ 국제필름페스티벌 수상
# 1년 넘게 집콕했는데…‘살고 싶은 섬’에서 ‘섬택근무’ 어때요?
# “깜깜이 월급 일방적 통지…30년 쌓인 불만 터졌다”
# “비트코인은 사기”라던 투자기관이 암호화폐 주목하는 이유는?
# 독일판 웰컴투비디오? 회원 40만 아동 성착취 영상 플랫폼 적발
# 민주당 대변인 “백신 부작용? 소화제 먹어도 사망하는 경우 있다”
#  뉴스
#  연예
#  스포츠

# %%
import requests
from bs4 import BeautifulSoup
res = requests.get('https://davelee-fun.github.io/blog/crawl_test')
soup = BeautifulSoup(res.content, 'html.parser')# 비정형 데이터

titles = soup.find_all('li', 'course')
for title in titles:
    print(title.get_text())
# Out:
# (왕초보) - 클래스 소개
# (왕초보) - 블로그 개발 필요한 준비물 준비하기
# (왕초보) - Github pages 설정해서 블로그 첫 페이지 만들어보기
# (왕초보) - 초간단 페이지 만들어보기
# (왕초보) - 이쁘게 테마 적용해보기
# (왕초보) - 마크다운 기초 이해하고, 실제 나만의 블로그 페이지 만들기
# (왕초보) - 다양한 마크다운 기법 익혀보며, 나만의 블로그 페이지 꾸며보기
# (초급) - 강사가 실제 사용하는 자동 프로그램 소개 [2]
# (초급) - 필요한 프로그램 설치 시연 [5]
# (초급) - 데이터를 엑셀 파일로 만들기 [9]
# (초급) -     엑셀 파일 이쁘게! 이쁘게! [8]
# (초급) -     나대신 주기적으로 파이썬 프로그램 실행하기 [7]
# (초급) - 파이썬으로 슬랙(slack) 메신저에 글쓰기 [40]
# (초급) - 웹사이트 변경사항 주기적으로 체크해서, 메신저로 알람주기 [12]
# (초급) - 네이버 API 사용해서, 블로그에 글쓰기 [42]
# (중급) - 자동으로 쿠팡파트너스 API 로 가져온 상품 정보, 네이버 블로그/트위터에 홍보하기 [412]

# %%
import requests
from bs4 import BeautifulSoup
res = requests.get('https://davelee-fun.github.io/blog/crawl_test')
soup = BeautifulSoup(res.content, 'html.parser')
section = soup.find('ul', id='dev_course_list')
titles = section.find_all('li','course')
for index, title in enumerate(titles):
    print(str(index + 1) + '.', title.get_text().split('-')[1].split('[')[0].strip())
# Out:
# 1. 강사가 실제 사용하는 자동 프로그램 소개
# 2. 필요한 프로그램 설치 시연
# 3. 데이터를 엑셀 파일로 만들기
# 4. 엑셀 파일 이쁘게! 이쁘게!
# 5. 나대신 주기적으로 파이썬 프로그램 실행하기
# 6. 파이썬으로 슬랙(slack) 메신저에 글쓰기
# 7. 웹사이트 변경사항 주기적으로 체크해서, 메신저로 알람주기
# 8. 네이버 API 사용해서, 블로그에 글쓰기
# 9. 자동으로 쿠팡파트너스 API 로 가져온 상품 정보, 네이버 블로그/트위터에 홍보하기

# %% [markdown]
# ## css selector 사용해서 크롤링

# %% [markdown]
# ### '>'기호표시 (하위 태그 선택0

# %%
import requests
from bs4 import BeautifulSoup

URL = 'https://davelee-fun.github.io/blog/crawl_test'
res = requests.get(URL)
soup = BeautifulSoup(res.text, 'html.parser')
# items = soup.select('body > ul > li')
# items = soup.select('ul > li')
items = soup.select('body > li')
for item in items:
    print(item.get_text())

# %% [markdown]
# ### ' ' 표시 (태그 선택)

# %%
import requests
from bs4 import BeautifulSoup

URL = 'https://davelee-fun.github.io/blog/crawl_test'
res = requests.get(URL)
soup = BeautifulSoup(res.text, 'html.parser')
# items = soup.select('body  ul li')
# items = soup.select('ul  li')
items = soup.select('body  li')
for item in items:
    print(item.get_text())
# Out:
# (왕초보) - 클래스 소개
# (왕초보) - 블로그 개발 필요한 준비물 준비하기
# (왕초보) - Github pages 설정해서 블로그 첫 페이지 만들어보기
# (왕초보) - 초간단 페이지 만들어보기
# (왕초보) - 이쁘게 테마 적용해보기
# (왕초보) - 마크다운 기초 이해하고, 실제 나만의 블로그 페이지 만들기
# (왕초보) - 다양한 마크다운 기법 익혀보며, 나만의 블로그 페이지 꾸며보기
# (초급) - 강사가 실제 사용하는 자동 프로그램 소개 [2]
# (초급) - 필요한 프로그램 설치 시연 [5]
# (초급) - 데이터를 엑셀 파일로 만들기 [9]
# (초급) -     엑셀 파일 이쁘게! 이쁘게! [8]
# (초급) -     나대신 주기적으로 파이썬 프로그램 실행하기 [7]
# (초급) - 파이썬으로 슬랙(slack) 메신저에 글쓰기 [40]
# (초급) - 웹사이트 변경사항 주기적으로 체크해서, 메신저로 알람주기 [12]
# (초급) - 네이버 API 사용해서, 블로그에 글쓰기 [42]
# (중급) - 자동으로 쿠팡파트너스 API 로 가져온 상품 정보, 네이버 블로그/트위터에 홍보하기 [412]

# %% [markdown]
# ### css class 이름으로 검색

# %%
import requests
from bs4 import BeautifulSoup

URL = 'https://davelee-fun.github.io/blog/crawl_test'
res = requests.get(URL)
soup = BeautifulSoup(res.text, 'html.parser')
items = soup.select('.course')
for item in items:
    print(item.get_text())
# Out:
# (왕초보) - 클래스 소개
# (왕초보) - 블로그 개발 필요한 준비물 준비하기
# (왕초보) - Github pages 설정해서 블로그 첫 페이지 만들어보기
# (왕초보) - 초간단 페이지 만들어보기
# (왕초보) - 이쁘게 테마 적용해보기
# (왕초보) - 마크다운 기초 이해하고, 실제 나만의 블로그 페이지 만들기
# (왕초보) - 다양한 마크다운 기법 익혀보며, 나만의 블로그 페이지 꾸며보기
# (초급) - 강사가 실제 사용하는 자동 프로그램 소개 [2]
# (초급) - 필요한 프로그램 설치 시연 [5]
# (초급) - 데이터를 엑셀 파일로 만들기 [9]
# (초급) -     엑셀 파일 이쁘게! 이쁘게! [8]
# (초급) -     나대신 주기적으로 파이썬 프로그램 실행하기 [7]
# (초급) - 파이썬으로 슬랙(slack) 메신저에 글쓰기 [40]
# (초급) - 웹사이트 변경사항 주기적으로 체크해서, 메신저로 알람주기 [12]
# (초급) - 네이버 API 사용해서, 블로그에 글쓰기 [42]
# (중급) - 자동으로 쿠팡파트너스 API 로 가져온 상품 정보, 네이버 블로그/트위터에 홍보하기 [412]

# %% [markdown]
# ### id 이름으로 검색

# %%
import requests
from bs4 import BeautifulSoup

URL = 'https://davelee-fun.github.io/blog/crawl_test'
res = requests.get(URL)
soup = BeautifulSoup(res.text, 'html.parser')
items = soup.select('#hobby_course_list')
for item in items:
    print(item.get_text())
# Out:
# (왕초보) - 클래스 소개
# (왕초보) - 블로그 개발 필요한 준비물 준비하기
# (왕초보) - Github pages 설정해서 블로그 첫 페이지 만들어보기
# (왕초보) - 초간단 페이지 만들어보기
# (왕초보) - 이쁘게 테마 적용해보기
# (왕초보) - 마크다운 기초 이해하고, 실제 나만의 블로그 페이지 만들기
# (왕초보) - 다양한 마크다운 기법 익혀보며, 나만의 블로그 페이지 꾸며보기

# %% [markdown]
# ### 태그.믈래스이름1.클래스이름2....

# %%
import requests
from bs4 import BeautifulSoup

URL = 'https://davelee-fun.github.io/blog/crawl_test'
res = requests.get(URL)
soup = BeautifulSoup(res.text, 'html.parser')
items = soup.select('li.course')
for item in items:
    print(item.get_text())
# Out:
# (왕초보) - 클래스 소개
# (왕초보) - 블로그 개발 필요한 준비물 준비하기
# (왕초보) - Github pages 설정해서 블로그 첫 페이지 만들어보기
# (왕초보) - 초간단 페이지 만들어보기
# (왕초보) - 이쁘게 테마 적용해보기
# (왕초보) - 마크다운 기초 이해하고, 실제 나만의 블로그 페이지 만들기
# (왕초보) - 다양한 마크다운 기법 익혀보며, 나만의 블로그 페이지 꾸며보기
# (초급) - 강사가 실제 사용하는 자동 프로그램 소개 [2]
# (초급) - 필요한 프로그램 설치 시연 [5]
# (초급) - 데이터를 엑셀 파일로 만들기 [9]
# (초급) -     엑셀 파일 이쁘게! 이쁘게! [8]
# (초급) -     나대신 주기적으로 파이썬 프로그램 실행하기 [7]
# (초급) - 파이썬으로 슬랙(slack) 메신저에 글쓰기 [40]
# (초급) - 웹사이트 변경사항 주기적으로 체크해서, 메신저로 알람주기 [12]
# (초급) - 네이버 API 사용해서, 블로그에 글쓰기 [42]
# (중급) - 자동으로 쿠팡파트너스 API 로 가져온 상품 정보, 네이버 블로그/트위터에 홍보하기 [412]

# %% [markdown]
# ### 복합 에제

# %%
import requests
from bs4 import BeautifulSoup

URL = 'https://davelee-fun.github.io/blog/crawl_test'
res = requests.get(URL)
soup = BeautifulSoup(res.text, 'html.parser')
# items = soup.select('ul#hobby_course_list > li.course')
items = soup.select('#hobby_course_list > li:nth-child(7)')
for item in items:
    print(item.get_text())
# Out:
# (왕초보) - 다양한 마크다운 기법 익혀보며, 나만의 블로그 페이지 꾸며보기

# %% [markdown]
# # 네이버 쇼핑 사이트 크롤링 하기1

# %%
import requests
from bs4 import BeautifulSoup

URL = 'https://search.shopping.naver.com/best100v2/main.nhn'
res = requests.get(URL)
soup = BeautifulSoup(res.text, 'html.parser')


# a 태그임ㄴ서 hrdf 속성 값이 특정한 값을 갖는 경우 탐색

data = soup.select('#popular_srch_lst')
# data = soup.select('#popular_srch_lst > li.on > span.txt > a')
# data = soup.select('#popular_srch_lst > li:nth-child(2) > span.txt > a')
for d in data:
    print(d.get_text())
# Out:
# 1위
# 면도기
#
# 상승1
#
#
# 2위
# 카네이션
#
# 상승1
#
#
# 3위
# 어버이날 용돈박스
#
# 하락2
#
#
# 4위
# 크록스
#
# 상승4
#
#
# 5위
# 닌텐도 스위치
#
# 상승1
#
#
# 6위
# 어버이날 선물
#
# 하락2
#
#
# 7위
# 크록스 키즈
#
# 하락2
#
#
# 8위
# 마스크
#
# 하락1
#
#
# 9위
# 에어팟 프로
#
# 유지
#
#
#
# 10위
# 팝잇
#
# 상승2

# %% [markdown]
# ### 패턴을이용해 여러개 뽑기

# %%
import requests
from bs4 import BeautifulSoup
categori = {
    0: '패션의류',
    1: '패션잡화',
    2: '화장품/미용',
    3: '디지털/가전'
}
for i in range(4):
    URL = 'https://search.shopping.naver.com/best100v2/detail.nhn?catId=5000000' + str(i)
    res = requests.get(URL)
    soup = BeautifulSoup(res.text, 'html.parser')


    # a 태그임ㄴ서 hrdf 속성 값이 특정한 값을 갖는 경우 탐색

#productListArea > ul > li:nth-child(2) > p > a
    for j in range(1,101):
        data = soup.select('#productListArea > ul > li:nth-child('+str(j)+') > p > a')
        for d in data:
            print(categori[i],j,'위 ',d.get_text().strip())
# Out:
# 패션의류 1 위  타미힐피거 반팔 티셔츠 남자 여자 면티 T3...
# 패션의류 2 위  캘빈클라인언더웨어 남성 모던코튼 6팩 드로...
# 패션의류 3 위  나이키 남성용 NSW 클럽 조거팬츠 BV2679
# 패션의류 4 위  스튜디오톰보이 테일러드 린넨자켓 9100212...
# 패션의류 5 위  타미힐피거 남녀공용 카라티 반팔티 피케 폴...
# 패션의류 6 위  지오다노 여 프렌치 테리 조거핏 팬츠 4115...
# 패션의류 7 위  나이키 SB 로고 드라이핏 반팔티 AR4209-01...
# 패션의류 8 위  아디다스 코어18 레인 자켓 바람막이 윈드브...
# 패션의류 9 위  메종키츠네 여성 폭스 헤드 반팔 WH AW0010...
# 패션의류 10 위  나이키 클럽 트레이닝 조거팬츠 BV2671 063
# 패션의류 11 위  써스데이아일랜드 프릴 반팔 소매 원피스 T...
# 패션의류 12 위  아디다스 M 삼선 윈드브레이커 GQ0600 GQ06...
# 패션의류 13 위  지오다노 여 TR 블레이저 솔리드 371501
# 패션의류 14 위  나이키 W 스우시 하이 라이즈 우븐 팬츠 CZ...
# 패션의류 15 위  아디다스 오버핏 데일리 바람막이 우븐소재...
# 패션의류 16 위  나이키 기능성 드라이핏 반팔티 레전드 718...
# 패션의류 17 위  메종키츠네 폭스헤드 패치 반팔티 AM00103K...
# 패션의류 18 위  트리플에이 무지티 반팔티 무지 반팔티셔츠...
# 패션의류 19 위  아디다스 바람막이 오운더런 자켓 M OWN TH...
# 패션의류 20 위  지오다노 여 나일론 조거팬츠 411522
# 패션의류 21 위  써스데이아일랜드 빈티지 페이즐리 원피스 ...
# 패션의류 22 위  리스트 아웃포켓 원버튼 여름 자켓 TWWJKK6...
# 패션의류 23 위  캘빈클라인진 21S S 여성 슬림핏 기본로고 ...
# 패션의류 24 위  나이키 스우시 반팔티 827021-100
# ...

# %% [markdown]
# ### 네이버주식 사이트 크롤링 하기

# %%
import requests
from bs4 import BeautifulSoup

URL = 'https://finance.naver.com/sise/'
res = requests.get(URL)
soup = BeautifulSoup(res.text, 'html.parser')


# a 태그임ㄴ서 hrdf 속성 값이 특정한 값을 갖는 경우 탐색

for i in range(1,6):
    data = soup.select('#contentarea > div.box_top_submain2 > div.rgt > ul.lst_major > li:nth-child('+str(i)+')')
    # data = soup.select('#popular_srch_lst > li.on > span.txt > a')
    # data = soup.select('#popular_srch_lst > li:nth-child(2) > span.txt > a')
    for d in data:
        print('지수이름:',d.find('a').get_text().strip(),"현재지수 :",d.find('span').get_text(),d.find('em').get_text())
# Out:
# 지수이름: 다우산업 현재지수 : 34,548.53 상승
# 지수이름: 나스닥 현재지수 : 13,632.84 상승
# 지수이름: 홍콩H 현재지수 : 10,756.37 상승
# 지수이름: 상해종합 현재지수 : 3,441.28 하락
# 지수이름: 니케이225 현재지수 : 29,331.37 상승

# %% [markdown]
# ## Urillib 라이브러리 사용법

# %% [markdown]
# ### requests 라이브러리와 urllib 라이브러리 비교

# %% [markdown]
# 빈칸

# %% [markdown]
# ### HTTP response code 크롤링할 페이지가 없는 경우 확인 방법

# %%
import requests
from bs4 import BeautifulSoup

res = requests.get('https://davelee-fun.github.io/')
if res.status_code != 200:
    print('페이지 없음')
else:
    soup = BeautifulSoup(res.content, 'html.parser')

    data = soup.select('h4.card-text')
    for item in data:
        print(item.get_text().strip())
# Out:
# 상품명: 보몽드 순면스퀘어 솔리드 누빔매트커버, 다크블루
# 상품명: 슈에뜨룸 선인장 리플 침구 세트, 베이지
# 상품명: 선우랜드 레인보우 2단 문걸이용 옷걸이 _중형, 화이트, 상세페이지참조
# 상품명: 보드래 헬로우 누빔 매트리스커버, 핑크
# 상품명: 보드래 퍼펙트 누빔 매트리스커버, 차콜
# 상품명: 피아블 클래식 방수 매트리스커버, 화이트
# 상품명: 더자리 에코항균 마이크로 매트리스커버, 밀키차콜그레이
# 상품명: 더자리 프레쉬 퓨어 매트리스 커버, 퓨어 차콜그레이
# 상품명: 몽쉐어 알러스킨 항균 매트리스 커버, 카키그레이
# 상품명: 쿠팡 브랜드 - 코멧 홈 40수 트윌 순면 100% 홑겹 매트리스커버, 그레이
# 상품명: 패브릭아트 항균 마이크로 원단 매트리스 커버, 아이보리
# 상품명: 바숨 순면 누빔 침대 매트리스커버, 차콜
# 상품명: WEMAX 다용도 문옷걸이, 화이트, 1개
# 상품명: 타카타카 프리미엄 나노 화이바 누빔 매트리스 커버, 젠틀핑핑
# 상품명: 보몽드 순면스퀘어 누빔매트커버, 다크그레이
# 상품명: 보드래 국내산 순면 60수 누빔 매트리스커버, 그레이

# %% [markdown]
# ### 여러페이지 한번에 크롤링 하는 기법

# %%
import requests
from bs4 import BeautifulSoup


for page_num in range(10):
    if page_num == 0:
        res = requests.get('https://davelee-fun.github.io/')
    else:
        res = requests.get('https://davelee-fun.github.io/page' + str(page_num + 1))
    soup = BeautifulSoup(res.content, 'html.parser')
    
    data = soup.select('h4.card-text')
    for item in data:
        print(str(page_num),'페이지',item.get_text().strip())
# Out:
# 0 페이지 상품명: 보몽드 순면스퀘어 솔리드 누빔매트커버, 다크블루
# 0 페이지 상품명: 슈에뜨룸 선인장 리플 침구 세트, 베이지
# 0 페이지 상품명: 선우랜드 레인보우 2단 문걸이용 옷걸이 _중형, 화이트, 상세페이지참조
# 0 페이지 상품명: 보드래 헬로우 누빔 매트리스커버, 핑크
# 0 페이지 상품명: 보드래 퍼펙트 누빔 매트리스커버, 차콜
# 0 페이지 상품명: 피아블 클래식 방수 매트리스커버, 화이트
# 0 페이지 상품명: 더자리 에코항균 마이크로 매트리스커버, 밀키차콜그레이
# 0 페이지 상품명: 더자리 프레쉬 퓨어 매트리스 커버, 퓨어 차콜그레이
# 0 페이지 상품명: 몽쉐어 알러스킨 항균 매트리스 커버, 카키그레이
# 0 페이지 상품명: 쿠팡 브랜드 - 코멧 홈 40수 트윌 순면 100% 홑겹 매트리스커버, 그레이
# 0 페이지 상품명: 패브릭아트 항균 마이크로 원단 매트리스 커버, 아이보리
# 0 페이지 상품명: 바숨 순면 누빔 침대 매트리스커버, 차콜
# 0 페이지 상품명: WEMAX 다용도 문옷걸이, 화이트, 1개
# 0 페이지 상품명: 타카타카 프리미엄 나노 화이바 누빔 매트리스 커버, 젠틀핑핑
# 0 페이지 상품명: 보몽드 순면스퀘어 누빔매트커버, 다크그레이
# 0 페이지 상품명: 보드래 국내산 순면 60수 누빔 매트리스커버, 그레이
# 1 페이지 상품명: 보드래 퍼펙트 누빔 매트리스커버, 베이지핑크
# 1 페이지 상품명: 쿠팡 브랜드 - 코멧 홈 40수 순면 누빔 매트리스커버, 챠콜
# 1 페이지 상품명: 바숨 순면 누빔 침대 매트리스커버, 화이트
# 1 페이지 상품명: 프랑떼 항균 방수 매트리스커버, 화이트
# 1 페이지 상품명: 보몽드 순면스퀘어 솔리드 누빔매트커버, 다크블루
# 1 페이지 상품명: 네이쳐리빙 피아블 클래식 방수 매트리스커버, 그레이
# 1 페이지 상품명: 쿠팡 브랜드 - 코멧 홈 순면 매트리스커버, 베이지
# 1 페이지 상품명: 타카타카 프리미엄 나노 화이바 누빔 매트리스 커버, 프렌치불독
# ...

# %%
import requests
from bs4 import BeautifulSoup

res = requests.get('https://davelee-fun.github.io/')
soup = BeautifulSoup(res.content, 'html.parser')

pages = soup.select('body > div.site-content > div.container > div.main-content > div > span > div')

for page_num in range(9):
    if page_num == 0:
        res = requests.get('https://davelee-fun.github.io/')
    else:
        res = requests.get('https://davelee-fun.github.io/page' + str(page_num + 1))
    
    
    data = soup.select('h4.card-text')
    for item in data:
        print(str(page_num),'페이지',item.get_text().strip())
# Out:
# 0 페이지 상품명: 보몽드 순면스퀘어 솔리드 누빔매트커버, 다크블루
# 0 페이지 상품명: 슈에뜨룸 선인장 리플 침구 세트, 베이지
# 0 페이지 상품명: 선우랜드 레인보우 2단 문걸이용 옷걸이 _중형, 화이트, 상세페이지참조
# 0 페이지 상품명: 보드래 헬로우 누빔 매트리스커버, 핑크
# 0 페이지 상품명: 보드래 퍼펙트 누빔 매트리스커버, 차콜
# 0 페이지 상품명: 피아블 클래식 방수 매트리스커버, 화이트
# 0 페이지 상품명: 더자리 에코항균 마이크로 매트리스커버, 밀키차콜그레이
# 0 페이지 상품명: 더자리 프레쉬 퓨어 매트리스 커버, 퓨어 차콜그레이
# 0 페이지 상품명: 몽쉐어 알러스킨 항균 매트리스 커버, 카키그레이
# 0 페이지 상품명: 쿠팡 브랜드 - 코멧 홈 40수 트윌 순면 100% 홑겹 매트리스커버, 그레이
# 0 페이지 상품명: 패브릭아트 항균 마이크로 원단 매트리스 커버, 아이보리
# 0 페이지 상품명: 바숨 순면 누빔 침대 매트리스커버, 차콜
# 0 페이지 상품명: WEMAX 다용도 문옷걸이, 화이트, 1개
# 0 페이지 상품명: 타카타카 프리미엄 나노 화이바 누빔 매트리스 커버, 젠틀핑핑
# 0 페이지 상품명: 보몽드 순면스퀘어 누빔매트커버, 다크그레이
# 0 페이지 상품명: 보드래 국내산 순면 60수 누빔 매트리스커버, 그레이
# 1 페이지 상품명: 보몽드 순면스퀘어 솔리드 누빔매트커버, 다크블루
# 1 페이지 상품명: 슈에뜨룸 선인장 리플 침구 세트, 베이지
# 1 페이지 상품명: 선우랜드 레인보우 2단 문걸이용 옷걸이 _중형, 화이트, 상세페이지참조
# 1 페이지 상품명: 보드래 헬로우 누빔 매트리스커버, 핑크
# 1 페이지 상품명: 보드래 퍼펙트 누빔 매트리스커버, 차콜
# 1 페이지 상품명: 피아블 클래식 방수 매트리스커버, 화이트
# 1 페이지 상품명: 더자리 에코항균 마이크로 매트리스커버, 밀키차콜그레이
# 1 페이지 상품명: 더자리 프레쉬 퓨어 매트리스 커버, 퓨어 차콜그레이
# ...

# %% [markdown]
# ## 크롤링해서 엑셀 파일로 데이터 저장

# %%
# !pip install openpyxl
# Out:
# ...
#   Using cached openpyxl-3.0.7-py2.py3-none-any.whl (243 kB)
# ...
#   Using cached et_xmlfile-1.1.0-py3-none-any.whl (4.7 kB)
# ...
# WARNING: You are using pip version 20.2.3; however, version 21.1.1 is available.
# You should consider upgrading via the 'c:\users\ad\appdata\local\programs\python\python38\python.exe -m pip install --upgrade pip' command.

# %% [markdown]
# ### 엑셀 파일만드는 함수 정의

# %%
import openpyxl

def write_excel_template(filename, sheetname, listdata):
    excel_file = openpyxl.Workbook()
    excel_sheet = excel_file.active
    excel_sheet.column_dimensions['A'].width = 100
    excel_sheet.column_dimensions['B'].width = 20

    if sheetname != '':
        excel_sheet.title = sheetname
    
    for item in listdata:
        excel_sheet.append(item)
    excel_file.save("C:\\apps\\webCrolling\\"+filename)
    excel_file.close()

# %% [markdown]
# ### 크롤링해서 엑셀 파일까지 만들기

# %%
import requests
from bs4 import BeautifulSoup

product_lists = list()

for page_num in range(10):
    if page_num == 0:
        res = requests.get('https://davelee-fun.github.io/')
    else:
        res = requests.get('https://davelee-fun.github.io/page' + str(page_num + 1))
    soup = BeautifulSoup(res.content, 'html.parser')
    
    data = soup.select('div.card')
    for item in data:
        product_name = item.select_one('div.card-body h4.card-text')
        product_date = item.select_one('div.wrapfooter span.post-date')
        product_info = [product_name.get_text().strip(), product_date.get_text()]
        product_lists.append(product_info)

# %% [markdown]
# ### 엑셀 파일로 데이터 저장

# %%
write_excel_template("hello.xlsx", 'ddd', product_lists)

# %% [markdown]
# # 2장 open API와 데이터 취급 포맷 이해와 활용

# %% [markdown]
# ## json 으로부터 값 받아오기

# %%
import json
data = '''
    {
    "lastBuildDate": "Thu, 06 May 2021 14:40:21 +0900",
    "total": 89100,
    "start": 1,
    "display": 10,
    "items": [
        {
            "title": "룰루팝, 퍼플키스와 'FIND YOU' 함께한다",
            "originallink": "http://www.topdaily.kr/news/articleView.html?idxno=103476",
            "link": "http://www.topdaily.kr/news/articleView.html?idxno=103476",
            "description": "뮤직비디오는 최근 <b>아이즈원</b>, 청하 등의 뮤직비디오를 제작한 Vikings League(바이킹스 리그)에서 촬영을 진행하여 더욱더 많은 사람들의 궁금증을 자아내고 있다. 메타버스 트렌드와 K-POP(케이팝)... ",
            "pubDate": "Thu, 06 May 2021 14:28:00 +0900"
        },
        {
            "title": "<b>아이즈원</b> 출신 김채원, 봄 감성 물씬… '처음부터 너와 나' 완벽 재해석",
            "originallink": "http://www.topdaily.kr/news/articleView.html?idxno=103472",
            "link": "http://www.topdaily.kr/news/articleView.html?idxno=103472",
            "description": "사진 = 울림엔터테인먼트 제공 톱데일리 서상현 기자 = <b>아이즈원</b>(IZ *ONE) 출신 김채원이 '음색 요정'다운... '울림 더 라이브' 영상은 <b>아이즈원</b> 이후 김채원의 첫 행보라 글로벌 팬들의 폭발적인 호응을 얻었다. 공개된... ",
            "pubDate": "Thu, 06 May 2021 14:28:00 +0900"
        },
        {
            "title": "김채원 홀로서기, 상큼미 물씬…‘처음부터 너와 나’ 커버 영상 호평",
            "originallink": "http://sports.khan.co.kr/news/sk_index.html?art_id=202105061359013&sec_id=540101&pt=nv",
            "link": "https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=106&oid=144&aid=0000734923",
            "description": "그룹 ‘<b>아이즈원</b>’ 출신 김채원이 ‘음색 요정’다운 매력으로 음악팬들을 사로잡았다. 홀로서기 행보를... ‘울림 더 라이브’ 영상은 <b>아이즈원</b> 이후 김채원의 첫 행보라 글로벌 팬들의 폭발적인 호응을 얻었다. 공개된... ",
            "pubDate": "Thu, 06 May 2021 14:00:00 +0900"
        },
        {
            "title": "유니버스 뮤직, 강다니엘 신곡 ‘Outerspace (Feat. 로꼬)’ 스케줄러 오픈",
            "originallink": "http://www.gameshot.net/common/con_view.php?code=GA6093761ca10c3",
            "link": "http://www.gameshot.net/common/con_view.php?code=GA6093761ca10c3",
            "description": "로꼬)’는 지난 1월 발매된 IZ*ONE(<b>아이즈원</b>) ‘D-D-DANCE’를 시작으로 2월 발매된 조수미‧비 ‘수호신(Guardians)’, 3월 박지훈 ‘Call U UP (Feat. 이하이) (Prod. Primary)’, 4월 (여자)아이들 ‘Last Dance (Prod. GroovyRoom)... ",
            "pubDate": "Thu, 06 May 2021 14:00:00 +0900"
        },
        {
            "title": "<b>아이즈원</b> 출신 김채원, ‘울림 더 라이브’로 첫 행보!",
            "originallink": "http://enews.imbc.com/News/RetrieveNewsInfo/313507",
            "link": "https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=106&oid=408&aid=0000121977",
            "description": "<b>아이즈원</b>(IZ *ONE) 출신 김채원이 ‘음색 요정’다운 매력으로 음악팬들을 사로잡았다. 김채원은 지난 5일... ‘울림 더 라이브’ 영상은 <b>아이즈원</b> 이후 김채원의 첫 행보라 글로벌 팬들의 폭발적인 호응을 얻었다. 공개된... ",
            "pubDate": "Thu, 06 May 2021 13:58:00 +0900"
        },
        {
            "title": "강다니엘X로꼬, 13일 신곡 ‘Outerspace (Feat. 로꼬)’ 발매",
            "originallink": "http://star.mbn.co.kr/view.php?year=2021&no=436842&refer=portal",
            "link": "https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=106&oid=057&aid=0001574212",
            "description": "로꼬)’는 지난 1월 발매된 IZ*ONE(<b>아이즈원</b>) ‘D-D-DANCE’를 시작으로 2월 발매된 조수미‧비 ‘수호신(Guardians)’, 3월 박지훈 ‘Call U UP (Feat. 이하이) (Prod. Primary)’, 4월 (여자)아이들 ‘Last Dance (Prod. GroovyRoom)... ",
            "pubDate": "Thu, 06 May 2021 13:42:00 +0900"
        },
        {
            "title": "김채원, <b>아이즈원</b>→홀로서기 대성공",
            "originallink": "https://hankookilbo.com/News/Read/A2021050613170003286?did=NA",
            "link": "https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=106&oid=469&aid=0000602498",
            "description": "그룹 <b>아이즈원</b>(IZ*ONE) 출신 김채원이 성공적인 홀로서기를 알렸다. 김채원은 지난 5일 오후 8시 '울림 더... '울림 더 라이브' 영상은 <b>아이즈원</b> 이후 김채원의 첫 행보로 글로벌 팬들의 폭발적인 호응을 얻었다. 공개된... ",
            "pubDate": "Thu, 06 May 2021 13:36:00 +0900"
        },
        {
            "title": "‘불꽃미남’ 차인표X신성우, 90년대 하이틴 스타들의 버킷 리스트 도전기",
            "originallink": "http://www.sportsworldi.com/newsView/20210506510132",
            "link": "https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=106&oid=396&aid=0000580529",
            "description": "특히 팬들의 방문으로 담벼락마저 무너지게 하였던 이들의 전성기 시절은 특별 MC로 출격한 <b>아이즈원</b> 예나마저도 불꽃미남의 팬클럽인 ‘불꽃 씨스터즈’에 합류하게 하였다고 전해져 오늘 방송에 기대가 고조되고... ",
            "pubDate": "Thu, 06 May 2021 13:35:00 +0900"
        },
        {
            "title": "김채원, <b>아이즈원</b> 활동 종료 후 '울림 더 라이브'로 첫 행보",
            "originallink": "http://www.xportsnews.com/?ac=article_view&entry_id=1421205",
            "link": "https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=106&oid=311&aid=0001295506",
            "description": "그룹 <b>아이즈원</b>(IZ *ONE) 출신 김채원이 ‘음색 요정’다운 매력으로 음악팬들을 사로잡았다. 김채원은 지난 5일... ‘울림 더 라이브’ 영상은 <b>아이즈원</b> 이후 김채원의 첫 행보라 글로벌 팬들의 폭발적인 호응을 얻었다.... ",
            "pubDate": "Thu, 06 May 2021 13:30:00 +0900"
        },
        {
            "title": "김채원, <b>아이즈원</b> 활동 종료 후 첫 행보..‘처음부터 너와 나’ 완벽 커버",
            "originallink": "http://biz.heraldcorp.com/view.php?ud=202105061327429060226_1",
            "link": "https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=106&oid=112&aid=0003430109",
            "description": "<b>아이즈원</b>(IZ *ONE) 출신 김채원이 ‘음색 요정’다운 매력으로 음악팬들을 사로잡았다. 김채원은 지난 5일 오후... ‘울림 더 라이브’ 영상은 <b>아이즈원</b> 이후 김채원의 첫 행보라 글로벌 팬들의 폭발적인 호응을 얻었다.... ",
            "pubDate": "Thu, 06 May 2021 13:29:00 +0900"
        }
    ]
}
'''

json_data = json.loads(data)
print(json_data["items"][0]['title'])
print(json_data["items"][0]['link'])
print(json_data["items"][0]['description'])
# Out:
# 룰루팝, 퍼플키스와 'FIND YOU' 함께한다
# http://www.topdaily.kr/news/articleView.html?idxno=103476
# 뮤직비디오는 최근 <b>아이즈원</b>, 청하 등의 뮤직비디오를 제작한 Vikings League(바이킹스 리그)에서 촬영을 진행하여 더욱더 많은 사람들의 궁금증을 자아내고 있다. 메타버스 트렌드와 K-POP(케이팝)...

# %% [markdown]
# ## 네이버 공공 api 쓰기

# %%
import requests
import pprint

# header 에 넣을 id, pw
client_id = '5JdGkYvLuXbyk5oUhJp6'
client_secret = '61D7pP3VAZ'
# 화면에 뿌릴것들
search = '전기차'
display = '5'
start_num = '5'
# 위의 변수들 적용
naver_open_api = 'https://openapi.naver.com/v1/search/news.json?query='+search+'&display='+display+'&start='+start_num
header_params  = {'X-naver-client-id' : client_id, 'X-naver-client-secret' : client_secret}
res = requests.get(naver_open_api, headers = header_params)

if res.status_code == 200:
    data = res.json()
    for index, item in enumerate(data['items']):
        print(index + 1, item['title'], item['link'])
else:
    print("Error Code:", res.status_code)
# Out:
# 1 LG·SK 특허 전문인재 채용…제2 배터리戰 대비한다 http://www.whitepaper.co.kr/news/articleView.html?idxno=205689
# 2 시트로엥 변신 미니밴, 에이미 카고 http://www.earlyadopter.co.kr/149702
# 3 테슬라, 세계에서 잘 나가지만...한국 판매량은 여전히 ‘들쭉날쭉’ https://www.ekn.kr/web/view.php?key=20210507010001221
# 4 각종 교통호재 품은 지식산업센터 ‘디원시티 시그니처’ 분양 https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=101&oid=011&aid=0003907071
# 5 SKIET, 목표주가 계산해보니 14만8000원...왜? http://www.itooza.com/common/iview.php?no=2021050708561126701

# %%
import requests
import openpyxl

client_id = '5JdGkYvLuXbyk5oUhJp6'
client_secret = '61D7pP3VAZ'
start, num = 1, 0
# 화면에 뿌릴것들
search = '아이즈원 attitude'
display = '5'
start_num = '5'
excel_filename = 'izone.xlsx'
excel_file = openpyxl.Workbook()
excel_sheet = excel_file.active
excel_sheet.column_dimensions['B'].width = 100
excel_sheet.column_dimensions['C'].width = 100
excel_sheet.append(['랭킹','제목','링크'])

for index in range(10):
    start_number = start + (index * 100)
    naver_open_api = 'https://openapi.naver.com/v1/search/news.json?query='+search+'&display='+display+'&start='+str(start_number)
    header_params  = {'X-naver-client-id' : client_id, 'X-naver-client-secret' : client_secret}
    res = requests.get(naver_open_api, headers = header_params)
    if res.status_code == 200:
        data = res.json()
        for index, item in enumerate(data['items']):
            num += 1
            excel_sheet.append([num, item['title'], item['link']])
            print(index + 1, item['title'], item['link'])
    else:
        print("Error Code:", res.status_code)
        
excel_file.save("C:\\apps\\webCrolling\\"+excel_filename)
excel_file.close()
# Out:
# 1 이제 12명의 소녀가 흩어지는 순간..아듀! <b>아이즈원</b> [문완식의 톡식] https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=106&oid=108&aid=0002951026
# 2 소유, 파격적인 뒤태 노출… &quot;열심히 다이어트, 내 몸매는 노력형&quot; http://www.newsworks.co.kr/news/articleView.html?idxno=544946
# 3 [화보] 소유, &quot;하고 싶은 음악 하며 필모그래피 쌓고파&quot; http://www.nbnnews.co.kr/news/articleView.html?idxno=494422
# 4 &quot;노력형 몸매&quot;…소유, 파격 뒤태 노출 '섹시美' 폭발 [화보] https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=106&oid=311&aid=0001292514
# 5 소유, 62.4kg 경도비만 탈출하더니 파격 뒤태 노출 https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=106&oid=109&aid=0004395678
# 1 소유X<b>아이즈원</b>XpH-1, 신곡 'ZERO:<b>ATTITUDE</b>' 오늘(15일) 발매 https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=106&oid=112&aid=0003399535
# 2 소유·<b>아이즈원</b>·pH-1, 신곡 'ZERO:<b>ATTITUDE</b>' MV 티저 공개… 당당한 자신감 http://www.newsworks.co.kr/news/articleView.html?idxno=527493
# ...

# %% [markdown]
# ## 공공api

# %% [markdown]
# ### json 으로 받아오기

# %%
import requests

serviceKey = '?serviceKey=lJ%2F3p39Oo9MGopDLSyAj8TkGCJ01DaEx0JrrSmZyZZZKafeFH6vo7%2B4rCzMn8b1%2FLCXe4JhOOX9kRwc14WyPiw%3D%3D'
returnType = '&returnType=json'
numOfRows = '&numOfRows=100'
sidoName = '&sidoName=부산'
service_url = 'http://apis.data.go.kr/B552584/ArpltnInforInqireSvc/getMinuDustFrcstDspth'
open_api = service_url+serviceKey+returnType+numOfRows+sidoName
print(open_api)

res = requests.get(open_api)

print(res.text)
# Out:
# http://apis.data.go.kr/B552584/ArpltnInforInqireSvc/getMinuDustFrcstDspth?serviceKey=lJ%2F3p39Oo9MGopDLSyAj8TkGCJ01DaEx0JrrSmZyZZZKafeFH6vo7%2B4rCzMn8b1%2FLCXe4JhOOX9kRwc14WyPiw%3D%3D&returnType=json&numOfRows=100&sidoName=부산
# ...

# %%
import requests
open_api = 'http://apis.data.go.kr/B552584/ArpltnInforInqireSvc/getCtprvnRltmMesureDnsty'
serviceKey = '?serviceKey=lJ%2F3p39Oo9MGopDLSyAj8TkGCJ01DaEx0JrrSmZyZZZKafeFH6vo7%2B4rCzMn8b1%2FLCXe4JhOOX9kRwc14WyPiw%3D%3D'
returnType = '&returnType=json'
numOfRows = '&numOfRows=100'
sidoName = '&sidoName=부산'

res = requests.get(open_api+serviceKey+returnType+numOfRows+sidoName)
print(open_api+serviceKey+returnType+numOfRows+sidoName)
print(res.text)
#print(res.text)
if res.status_code == 200:
    data = res.json()
    print(data['response']['body']['items'])
    # for index, item in enumerate(data['items']):
    #     print (index, item)
else:
    print("Error Code:", res.status_code)
# Out:
# http://apis.data.go.kr/B552584/ArpltnInforInqireSvc/getCtprvnRltmMesureDnsty?serviceKey=lJ%2F3p39Oo9MGopDLSyAj8TkGCJ01DaEx0JrrSmZyZZZKafeFH6vo7%2B4rCzMn8b1%2FLCXe4JhOOX9kRwc14WyPiw%3D%3D&returnType=json&numOfRows=100&sidoName=부산
# ...

# %% [markdown]
# ### XML 포멧 이해와 공공 Open API 미세먼지 크롤링

# %%
# !pip install requests
# Out:
# ...
# WARNING: You are using pip version 20.2.3; however, version 21.1.1 is available.
# You should consider upgrading via the 'c:\users\ad\appdata\local\programs\python\python38\python.exe -m pip install --upgrade pip' command.

# %%
import requests
open_api = 'http://apis.data.go.kr/B552584/ArpltnInforInqireSvc/getCtprvnRltmMesureDnsty'
serviceKey = '?serviceKey=lJ%2F3p39Oo9MGopDLSyAj8TkGCJ01DaEx0JrrSmZyZZZKafeFH6vo7%2B4rCzMn8b1%2FLCXe4JhOOX9kRwc14WyPiw%3D%3D'
returnType = '&returnType=json'
numOfRows = '&numOfRows=100'
sidoName = '&sidoName=부산'

res = requests.get(open_api+serviceKey+returnType+numOfRows+sidoName)

#print(res.text)
if res.status_code == 200:
    data = res.json()
#     for index, item in enumerate(data['response']['body']['items']):
#         print (index, item)
#         print()
else:
    print("Error Code:", res.status_code)
    
print(data.keys())
print(type(data['response']))
print(data['response'].keys())
print(type(data['response']['body']))
print(data['response']['body'].keys())
print(data['response']['header'].keys())
print(type(data['response']['body']['totalCount']))
print(data['response']['body']['totalCount'])
print(type(data['response']['body']['items']))
print(len(data['response']['body']['items']))
print(len(data['response']['body']['items'][0]))
print(type(data['response']['body']['items'][0]))
# Out:
# dict_keys(['response'])
# <class 'dict'>
# dict_keys(['body', 'header'])
# <class 'dict'>
# dict_keys(['totalCount', 'items', 'pageNo', 'numOfRows'])
# dict_keys(['resultMsg', 'resultCode'])
# <class 'int'>
# 32
# <class 'list'>
# 32
# 20
# <class 'dict'>

# %% [markdown]
# response
#     body
#         totalCount
#             32
#         items
#
#         pageNo
#         numOfRows
#     header
#         resultMsg
#         resultCode

# %% [markdown]
# ### json 으로 가져오기

# %%
import requests
open_api = 'http://apis.data.go.kr/B552584/ArpltnInforInqireSvc/getCtprvnRltmMesureDnsty'
serviceKey = '?serviceKey=lJ%2F3p39Oo9MGopDLSyAj8TkGCJ01DaEx0JrrSmZyZZZKafeFH6vo7%2B4rCzMn8b1%2FLCXe4JhOOX9kRwc14WyPiw%3D%3D'
returnType = '&returnType=json'
numOfRows = '&numOfRows=100'
sidoName = '&sidoName=부산'

res = requests.get(open_api+serviceKey+returnType+numOfRows+sidoName)

#print(res.text)
if res.status_code == 200:
    data = res.json()
#     for index, item in enumerate(data['response']['body']['items']):
#         print (index, item)
#         print()
else:
    print("Error Code:", res.status_code)


response = data.get("response")
body = response.get("body")
total = body.get('totalCount')

print('totalcount',total)
items = body.get("items")

print(items[0]) 

print("---------------------")

sido = items[0].get("sidoName")

print(sido)
# Out:
# totalcount 32
# {'so2Grade': '1', 'coFlag': None, 'khaiValue': '84', 'so2Value': '0.002', 'coValue': '0.2', 'pm10Flag': None, 'o3Grade': '2', 'pm10Value': '50', 'khaiGrade': '2', 'sidoName': '부산', 'no2Flag': None, 'no2Grade': '1', 'o3Flag': None, 'so2Flag': None, 'dataTime': '2021-05-07 09:00', 'coGrade': '1', 'no2Value': '0.024', 'stationName': '광복동', 'pm10Grade': '2', 'o3Value': '0.037'}
# ---------------------
# 부산

# %% [markdown]
# ### xml 로 가져오기

# %%
! pip install bs4
# Out:
# ...
# WARNING: You are using pip version 20.2.3; however, version 21.1.1 is available.
# You should consider upgrading via the 'c:\users\ad\appdata\local\programs\python\python38\python.exe -m pip install --upgrade pip' command.

# %%
import requests
from bs4 import BeautifulSoup

open_api = 'http://apis.data.go.kr/B552584/ArpltnInforInqireSvc/getCtprvnRltmMesureDnsty'
serviceKey = '?serviceKey=lJ%2F3p39Oo9MGopDLSyAj8TkGCJ01DaEx0JrrSmZyZZZKafeFH6vo7%2B4rCzMn8b1%2FLCXe4JhOOX9kRwc14WyPiw%3D%3D'
returnType = '&returnType=xml'
numOfRows = '&numOfRows=100'
sidoName = '&sidoName=부산'

res = requests.get(open_api+serviceKey+returnType+numOfRows+sidoName)

soup = BeautifulSoup(res.content, 'html.parser')
data = soup.find_all('item')


for item in data:   
    print(item.find('sidoname').text)
    print()
# Out:
# 부산
#
# 부산
#
# 부산
#
# 부산
#
# 부산
#
# 부산
#
# 부산
#
# 부산
#
# 부산
#
# 부산
#
# 부산
#
# 부산
#
# 부산
#
# 부산
#
# 부산
#
# 부산
#
# 부산
#
# 부산
#
# 부산
#
# 부산
#
# 부산
#
# 부산
#
# 부산
#
# 부산
#
# 부산
#
# 부산
#
# 부산
#
# 부산
#
# 부산
#
# 부산
#
# 부산
#
# 부산

# %% [markdown]
# ## 크롤링과 프로그래밍 정규 표현식 self_reviewing!

# %%
# !pip install bs4
# Out:
# ...
# WARNING: You are using pip version 20.2.3; however, version 21.1.1 is available.
# You should consider upgrading via the 'c:\users\ad\appdata\local\programs\python\python38\python.exe -m pip install --upgrade pip' command.

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
import re

URL = 'https://davelee-fun.github.io/blog/crawl_test'
res = urlopen(URL)
soup = BeautifulSoup(res, 'html.parser')

data = soup.select('ul#dev_course_list  li.course')
for item in data:
    print(item.get_text())
# Out:
# (초급) - 강사가 실제 사용하는 자동 프로그램 소개 [2]
# (초급) - 필요한 프로그램 설치 시연 [5]
# (초급) - 데이터를 엑셀 파일로 만들기 [9]
# (초급) -     엑셀 파일 이쁘게! 이쁘게! [8]
# (초급) -     나대신 주기적으로 파이썬 프로그램 실행하기 [7]
# (초급) - 파이썬으로 슬랙(slack) 메신저에 글쓰기 [40]
# (초급) - 웹사이트 변경사항 주기적으로 체크해서, 메신저로 알람주기 [12]
# (초급) - 네이버 API 사용해서, 블로그에 글쓰기 [42]
# (중급) - 자동으로 쿠팡파트너스 API 로 가져온 상품 정보, 네이버 블로그/트위터에 홍보하기 [412]

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
import re

URL = 'https://davelee-fun.github.io/blog/crawl_test'
res = urlopen(URL)
soup = BeautifulSoup(res, 'html.parser')

data = soup.select('ul#dev_course_list  li.course')
for item in data:
    print(re.sub('\[[0-9]+\]','',item.get_text()))
# Out:
# (초급) - 강사가 실제 사용하는 자동 프로그램 소개
# (초급) - 필요한 프로그램 설치 시연
# (초급) - 데이터를 엑셀 파일로 만들기
# (초급) -     엑셀 파일 이쁘게! 이쁘게!
# (초급) -     나대신 주기적으로 파이썬 프로그램 실행하기
# (초급) - 파이썬으로 슬랙(slack) 메신저에 글쓰기
# (초급) - 웹사이트 변경사항 주기적으로 체크해서, 메신저로 알람주기
# (초급) - 네이버 API 사용해서, 블로그에 글쓰기
# (중급) - 자동으로 쿠팡파트너스 API 로 가져온 상품 정보, 네이버 블로그/트위터에 홍보하기

# %% [markdown]
# ## 크롤링 프로그램 완성 클롤링한 데이터에서 다시 크롤링 하기

# %% [markdown]
# ### 이커머스(지마켓) 베스트100 상품 타이틀/가격 추출하기

# %%
import requests
from bs4 import BeautifulSoup

URL = 'http://corners.gmarket.co.kr/Bestsellers?viewType=G&groupCode=G06'
res = requests.get(URL)
if res.status_code == 200:
    soup = BeautifulSoup(res.content, 'html.parser')
    
    bestlists = soup.select('#gBestWrap > div > div:nth-child(5) > div:nth-child(3) > ul > li')
    
    
    for index,item in enumerate(bestlists):
        print('상품 : ',item.select(f"li:nth-child({index+1}) > a")[0].get_text())
        print('가격 : ',item.select(f"li:nth-child({index+1}) > div.item_price > div.s-price > strong > span > span")[0].get_text())
        print()
else:
    print('그런사이트 없습니다.')
# Out:
# 상품 :  [자우버]렌즈케어 200매 렌즈클리너 일회용 안경닦이 티슈
# 가격 :  9,400원
#
# 상품 :  닌텐도 스위치 슈퍼 마리오 3D 월드 + 퓨리 월드 c
# 가격 :  59,020원
#
# 상품 :  [샤오미]xiaomi 미TV 스틱/1080P/한국어 지원/글로벌 버전
# 가격 :  41,200원
#
# 상품 :  [유닉스]메탈티 무광블랙 1600W 헤어 드라이기 UN-A1610 접이식
# 가격 :  21,900원
#
# 상품 :  [닌텐도]스위치 슈퍼 마리오 파티
# 가격 :  58,900원
#
# 상품 :  [비달사순]비달사순 2000W 전문가용 헤어드라이기 VSD5129K
# 가격 :  20,800원
#
# 상품 :  [쉴드플러스]21년형+10%쿠폰)최고급형 써큘레이터 선풍기 리모컨
# 가격 :  37,900원
#
# 상품 :  네스프레소 에센자 C30 XN1101 미니 커피머신
# 가격 :  111,000원
#
# 상품 :  (21년형+10%쿠폰)르젠 2세대 BLDC 선풍기 LZEF-DC02
# 가격 :  69,800원
#
# 상품 :  [비달사순]비달사순 에어 봉고데기/매직기/아이롱 VSAS80PIK
# 가격 :  32,800원
#
# 상품 :  최신형) 무선 셀카봉 블루투스 핸드폰 삼각대 거치대
# 가격 :  18,900원
#
# 상품 :  [단미]샌드위치 크로플 와플 메이커 화이트(DA-SAN01)
# 가격 :  39,800원
#
# 상품 :  [유닉스]메탈릭 레트로 파워맥스 2000W 헤어드라이기 UN-B1643
# 가격 :  37,900원
#
# 상품 :  [삼성전자]갤럭시 핏2 SM-R220 스마트밴드 10%할인
# 가격 :  49,500원
#
# 상품 :  [일렉트로룩스](최초가 469000원) 18V 파워PRO ZB3423BO
# 가격 :  184,000원
#
# 상품 :  [비보북]ASUS 노트북 D515DA-BQ270 /라이젠/사무인강용노트북
# 가격 :  399,000원
#
# ...

# %% [markdown]
# #gBestWrap > div > div:nth-child(5) > div:nth-child(3) > ul > li:nth-child(1) > a
# #gBestWrap > div > div:nth-child(5) > div:nth-child(3) > ul > li:nth-child(2) > a
#
# #gBestWrap > div > div:nth-child(5) > div:nth-child(3) > ul > li:nth-child(198) > a

# %% [markdown]
# #gBestWrap > div > div:nth-child(5) > div:nth-child(3) > ul > li:nth-child(198) > div.item_price > div.s-price > strong > span > span

# %% [markdown]
# * http://corners.gmarket.co.kr/Bestsellers?viewType=G&groupCode=G01
# * http://corners.gmarket.co.kr/Bestsellers?viewType=G&groupCode=G02
#
#
# * http://corners.gmarket.co.kr/Bestsellers?viewType=G&groupCode=G12

# %% [markdown]
# ### 올리브영 사이트 받아오기

# %% [markdown]
# #### 내부 태그 구조

# %% [markdown]
# 컨테이너
# #Container > div.best-area > div.TabsConts.on
# 리스트카드
# #Container > div.best-area > div.TabsConts.on > ul:nth-child(1)
# #Container > div.best-area > div.TabsConts.on > ul:nth-child(2)
# #Container > div.best-area > div.TabsConts.on > ul:nth-child(25)
# 이름
# #Container > div.best-area > div.TabsConts.on > ul:nth-child(1) > li.flag > div > div > a > p
# #Container > div.best-area > div.TabsConts.on > ul:nth-child(1) > li:nth-child(2) > div > div > a > p
# #Container > div.best-area > div.TabsConts.on > ul:nth-child(1) > li:nth-child(3) > div > div > a > p
#
# #Container > div.best-area > div.TabsConts.on > ul:nth-child(2) > li.flag > div > div > a > p
# #Container > div.best-area > div.TabsConts.on > ul:nth-child(2) > li:nth-child(2) > div > div > a > p
# 가격
# #Container > div.best-area > div.TabsConts.on > ul:nth-child(1) > li.flag > div > p.prd_price > span > span

# %%
bestlists_list = soup.select('#Container > div.best-area > div.TabsConts.on > ul:nth-child(1) >li')
print('갯수',len(bestlists_list))
print(bestlists_list[0])
# Out:
# 갯수 4
# <li class="flag">
# ...

# %%
import requests
from bs4 import BeautifulSoup

URL = 'https://www.oliveyoung.co.kr/store/main/getBestList.do'
res = requests.get(URL)
if res.status_code == 200:
    soup = BeautifulSoup(res.content, 'html.parser')
    
    bestlists_container = soup.select('#Container > div.best-area > div.TabsConts.on')
    
    # 리스트 뽑기:
    for index, bestlists_card in enumerate(bestlists_container[0]):
        # 아이템 뽑기
        if index%2 == 1:
            for i in range(1,5):
                # 이름
                item_name = bestlists_card.select(f"ul:nth-child({int((index+1)/2) }) > li:nth-child({i}) > div > div > a > p")
                print((int((index+1)/2)-1)*4+i,'위',item_name[0].get_text())
                
                # 가격
                item_price = bestlists_card.select(f"ul:nth-child({int((index+1)/2) }) > li:nth-child({i}) > div p.prd_price > span > span")
                print('가격 : ',item_price[0].get_text())
            print()
            
else:
    print('그런사이트 없습니다.')

# %%
import requests
from bs4 import BeautifulSoup

URL = 'https://www.oliveyoung.co.kr/store/main/getBestList.do'
res = requests.get(URL)
if res.status_code == 200:
    soup = BeautifulSoup(res.content, 'html.parser')
    
    bestlists_container = soup.select('#Container > div.best-area > div.TabsConts.on')
    
    # 리스트 뽑기:
    for index, bestlists_card in enumerate(bestlists_container[0]):
        # 아이템 뽑기
        if index%2 == 1:
            for i in range(1,5):
                # 이름
                item_name = bestlists_card.select(f"ul:nth-child({int((index+1)/2) }) > li:nth-child({i}) > div > div > a > p")
                print((int((index+1)/2)-1)*4+i,'위',item_name[0].get_text())
                
                # 가격
                item_price = bestlists_card.select(f"ul:nth-child({int((index+1)/2) }) > li:nth-child({i}) > div p.prd_price > span > span")
                print('가격 : ',item_price[0].get_text())
            print()
            
else:
    print('그런사이트 없습니다.')
# Out:
# 1 위 라운드랩 자작나무 수분크림 1+1기획(2103)
# 가격 :  32,000
# 2 위 바비 브라운 엑스트라 립 틴트 베어 라즈베리 1+1 기획
# 가격 :  43,000
# 3 위 락토핏 생유산균 골드 30포 더블 기획(2105)
# 가격 :  21,800
# 4 위 ★민스코P!CK★ 바이오힐보 판테놀시카 블레미쉬크림 대용량 TOP 기획(75mL+30mL+5mL)
# 가격 :  32,000
#
# 5 위 라운드랩 자작나무 수분 선크림 1+1기획
# 가격 :  25,000
# 6 위 [1+1한정]한율 어린쑥 크림★로우로우 파우치 한정기획
# 가격 :  34,000
# 7 위 마녀공장 퓨어 클렌징 오일 300ml 증량 기획 (+퓨어 폼 20ml 증정)
# 가격 :  25,000
# 8 위 ★올리브영 단독★ 스킨푸드 캐롯 카로틴 패드 기획(캐롯크림 30ml 증정)
# 가격 :  26,000
#
# 9 위 에뛰드 그림자 쉐딩 10g (브러쉬 증정기획)
# 가격 :  18,000
# 10 위 코스노리 롱 액티브 아이래쉬 세럼 속눈썹영양제 9g
# 가격 :  14,000
# 11 위 오쏘몰 이뮨 멀티비타민&미네랄 30입 (1개월분)
# 가격 :  118,000
# 12 위 유세린 하이알루론 아이크림 15ml 기획 (+나이트크림 20ml 증정) #보습탄력#1등아이크림
# 가격 :  51,000
#
# 13 위 메이크프렘 세이프미 릴리프 모이스처 클렌징폼 150ml 1+1 기획
# 가격 :  16,000
# 14 위 셀퓨전씨 레이저 썬스크린 스페셜 기획세트 (60ml+20ml)
# 가격 :  29,400
# 15 위 [대용량] 마녀공장 비피다 바이옴 콤플렉스 앰플 80ml + 앰플 12ml+토너 30ml+로션 30ml
# 가격 :  39,000
# 16 위 ★윤스테이 노출상품★아비브 어성초 스팟 패드 카밍터치 더블 기획
# 가격 :  42,000
#
# 17 위 아누아 어성초 77 토너 500ml (대용량)
# 가격 :  45,000
# ...

# %% [markdown]
# ## 결과 엑셀로 집어넣기 (지마켓)

# %%
# !pip install openpyxl
# Out:
# ...
# WARNING: You are using pip version 20.2.3; however, version 21.1.1 is available.
# You should consider upgrading via the 'c:\users\ad\appdata\local\programs\python\python38\python.exe -m pip install --upgrade pip' command.

# %%
import requests, openpyxl
from bs4 import BeautifulSoup
import re

link_re = re.compile('^http://')
excel_file = openpyxl.Workbook()
excel_sheet = excel_file.active
excel_sheet.append(['랭킹', '상품명', '판매가격', '상품상세링크', '판매업체'])
excel_sheet.column_dimensions['B'].width = 80
excel_sheet.column_dimensions['C'].width = 20
excel_sheet.column_dimensions['D'].width = 80
excel_sheet.column_dimensions['E'].width = 20

res = requests.get('http://corners.gmarket.co.kr/Bestsellers?viewType=G&groupCode=G06')
soup = BeautifulSoup(res.content, 'html.parser')

bestlists = soup.select('div.best-list')
bestitems = bestlists[1]
products = bestitems.select('ul > li')

for index, product in enumerate(products):
    title = product.select_one('a.itemname')
    price = product.select_one('div.s-price > strong')
    if link_re.match(title['href']):             # 2020.07.25 업데이트 (지마켓 일부 상품 태그 변경, 공지사항 참조부탁드림)
        res_info = requests.get(title['href'])
        soup_info = BeautifulSoup(res_info.content, 'html.parser')
        # 2021.02.22 수정 사항
        # 웹사이트가 변경되어, 다음과 같이 작성해야 정상 크롤링이 되는 것으로 보입니다.
        # 기존 코드: provider_info = soup_info.select_one('div.item-topinfo > div.item-topinfo_headline > p > a > strong')
        provider_info = soup_info.select_one("div.item-topinfo_headline span.text__seller > a")
        print(index + 1, title.get_text(), price.get_text(), title['href'], provider_info.get_text())
        excel_sheet.append([index + 1, title.get_text(), price.get_text(), title['href'], provider_info.get_text()])
        excel_sheet.cell(row=index+2 , column=4).hyperlink = title['href']
        
        
cell_A1 = excel_sheet['A1'] # 셀 선택하기
cell_A1.alignment = openpyxl.styles.Alignment(horizontal='center') # 중앙정렬하기
cell_A1.font = openpyxl.styles.Font(color="01579B") # 폰트 색깔 바꾸기

# 색상값 찾기: https://material.io/design/color/#tools-for-picking-colors
cell_B1 = excel_sheet['B1'] # 셀 선택하기
cell_B1.alignment = openpyxl.styles.Alignment(horizontal='center') # 중앙정렬하기
cell_B1.font = openpyxl.styles.Font(color="01579B") # 폰트 색깔 바꾸기

# 색상값 찾기: https://material.io/design/color/#tools-for-picking-colors
cell_C1 = excel_sheet['C1'] # 셀 선택하기
cell_C1.alignment = openpyxl.styles.Alignment(horizontal='center') # 중앙정렬하기
cell_C1.font = openpyxl.styles.Font(color="01579B") # 폰트 색깔 바꾸기

# 색상값 찾기: https://material.io/design/color/#tools-for-picking-colors
cell_D1 = excel_sheet['D1'] # 셀 선택하기
cell_D1.alignment = openpyxl.styles.Alignment(horizontal='center') # 중앙정렬하기
cell_D1.font = openpyxl.styles.Font(color="01579B") # 폰트 색깔 바꾸기

# 색상값 찾기: https://material.io/design/color/#tools-for-picking-colors
cell_E1 = excel_sheet['E1'] # 셀 선택하기
cell_E1.alignment = openpyxl.styles.Alignment(horizontal='center') # 중앙정렬하기
cell_E1.font = openpyxl.styles.Font(color="01579B") # 폰트 색깔 바꾸기

# 색상값 찾기: https://material.io/design/color/#tools-for-picking-colors
excel_file.save('BESTPRODUCT_COM_GMARKET.xlsx')
excel_file.close()
# Out:
# 1 [자우버]렌즈케어 200매 렌즈클리너 일회용 안경닦이 티슈 9,400원 http://item.gmarket.co.kr/Item?goodscode=797037966&ver=637559849322853156 앤엑스라인
# 2 닌텐도 스위치 슈퍼 마리오 3D 월드 + 퓨리 월드 c 59,020원 http://item.gmarket.co.kr/Item?goodscode=2007957912&ver=637559849322853156 (주)컴퓨존
# 3 [샤오미]xiaomi 미TV 스틱/1080P/한국어 지원/글로벌 버전 41,200원 http://item.gmarket.co.kr/Item?goodscode=1994586227&ver=637559849322853156 미하우
# 4 [유닉스]메탈티 무광블랙 1600W 헤어 드라이기 UN-A1610 접이식 21,900원 http://item.gmarket.co.kr/Item?goodscode=1824005992&ver=637559849322853156 스마일배송
# 5 [비달사순]비달사순 2000W 전문가용 헤어드라이기 VSD5129K 20,800원 http://item.gmarket.co.kr/Item?goodscode=1807976048&ver=637559849322853156 스마일배송
# 6 [닌텐도]스위치 슈퍼 마리오 파티 58,900원 http://item.gmarket.co.kr/Item?goodscode=1853251769&ver=637559849322853156 지피클럽
# 7 [쉴드플러스]21년형+10%쿠폰)최고급형 써큘레이터 선풍기 리모컨 37,900원 http://item.gmarket.co.kr/Item?goodscode=2099672668&ver=637559849322853156 스마일배송
# ...
